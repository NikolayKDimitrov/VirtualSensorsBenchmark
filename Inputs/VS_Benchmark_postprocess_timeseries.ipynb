# %%
from wetb.hawc2 import Hawc2io
import numpy as np
import pandas as pd

# %%
# Just check how it works
Nfiles = 1

# %%
for i in range(Nfiles):
    print(i)
    fname = str('z:\StudyData\VS_Benchmark\TimeSeries\IEA_15MW_RWT_VS_BenchmarkStudy_PointNo' + str(i+1) + '.sel')
    res = Hawc2io.ReadHawc2(fname)
    sig = res.ReadAll()
    Data = pd.DataFrame(data = sig, columns = res.ChInfo[2])
# Out:
# 0

# %%
Data
# Out:
#              Time  shaft_rot angle  shaft_rot angle speed  pitch1 angle  \
# 0        0.000000         0.112497               1.909761      0.000074
# 1        0.021875         0.224994               1.909761      0.000074
# 2        0.021875         0.348741               1.909761      0.000221
# 3        0.043750         0.461238               1.910245      0.000515
# 4        0.043750         0.573735               1.910970      0.001103
# ...           ...              ...                    ...           ...
# 69995  699.956250       344.994550               7.501164      0.000515
# 69996  699.978125       345.444538               7.501406      0.000515
# 69997  699.978125       345.894526               7.501648      0.000515
# 69998  700.000000       346.344514               7.502373      0.000515
# 69999  700.000000       346.794502               7.503099      0.000515
#
#        pitch1 angle speed  pitch2 angle  pitch2 angle speed  pitch3 angle  \
# ...

# %%
Data.columns.values
# Out:
# array(['Time', 'shaft_rot angle', 'shaft_rot angle speed', 'pitch1 angle',
#        'pitch1 angle speed', 'pitch2 angle', 'pitch2 angle speed',
#        'pitch3 angle', 'pitch3 angle speed', 'Rotor speed',
#        'Aero rotor torque', 'Aero rotor power', 'Aero rotor thrust',
#        'generator_servo inpvec   1  mgen lss [nm]',
#        'generator_servo inpvec   2  pelec [w]',
#        'generator_servo inpvec   3  mframe [nm]',
#        'generator_servo inpvec   4  mgen hss [nm]',
#        'generator_servo inpvec   8  grid flag [0=run/1=stop]',
#        'MomentMx Mbdy:monopile nodenr:   4 coo: monopile  mudline',
#        'MomentMy Mbdy:monopile nodenr:   4 coo: monopile  mudline',
#        'MomentMz Mbdy:monopile nodenr:   4 coo: monopile  mudline',
#        'MomentMx Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
#        'MomentMy Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
# ...

# %%
# CHANGE CHANNEL NAMES

# General channels
Data.rename(columns = {'shaft_rot angle':'Rotor azimuth [deg]'}, inplace = True)
Data.rename(columns = {'shaft_rot angle speed':'Rotor rotational speed [rpm]'}, inplace = True)
Data.rename(columns = {'pitch1 angle':'Blade 1 pitch angle [deg]'}, inplace = True)
Data.rename(columns = {'pitch2 angle':'Blade 2 pitch angle [deg]'}, inplace = True)
Data.rename(columns = {'pitch3 angle':'Blade 3 pitch angle [deg]'}, inplace = True)
Data.rename(columns = {'MomentMz Mbdy:shaft nodenr:   1 coo: shaft  main bearing':'Low-speed shaft torque [kNm]'}, inplace = True)
Data.rename(columns = {'generator_servo inpvec   1  mgen lss [nm]':'Generator LSS torque [Nm]'}, inplace = True)
Data.rename(columns = {'generator_servo inpvec   2  pelec [w]':'Electrical power [W]'}, inplace = True)
Data.rename(columns = {'generator_servo inpvec   3  mframe [nm]':'Bedframe moment [Nm]'}, inplace = True)
Data.rename(columns = {'generator_servo inpvec   4  mgen hss [nm]':'Generator HSS torque [Nm]'}, inplace = True)

# Bending moments
Data.rename(columns = {'MomentMx Mbdy:monopile nodenr:   4 coo: monopile  mudline':'Mudline moment Mx[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMy Mbdy:monopile nodenr:   4 coo: monopile  mudline':'Mudline moment My[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMz Mbdy:monopile nodenr:   4 coo: monopile  mudline':'Mudline moment Mz[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMx Mbdy:monopile nodenr:   7 coo: monopile  waterline':'Waterline moment Mx[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMy Mbdy:monopile nodenr:   7 coo: monopile  waterline':'Waterline moment My[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMz Mbdy:monopile nodenr:   7 coo: monopile  waterline':'Waterline moment Mz[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMx Mbdy:tower nodenr:   1 coo: tower  tower base':'Tower base moment Mx[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMy Mbdy:tower nodenr:   1 coo: tower  tower base':'Tower base moment My[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMz Mbdy:tower nodenr:   1 coo: tower  tower base':'Tower base moment Mz[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMx Mbdy:tower nodenr:   5 coo: tower  tower mid':'Tower mid moment Mx[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMy Mbdy:tower nodenr:   5 coo: tower  tower mid':'Tower mid moment My[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMz Mbdy:tower nodenr:   5 coo: tower  tower mid':'Tower mid moment Mz[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMx Mbdy:tower nodenr:  10 coo: tower  tower yaw bearing':'Tower top moment Mx[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMy Mbdy:tower nodenr:  10 coo: tower  tower yaw bearing':'Tower top moment My[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMz Mbdy:tower nodenr:  10 coo: tower  tower yaw bearing':'Tower top moment Mz[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMx Mbdy:blade1 nodenr:   1 coo: blade1  blade 1 root':'Blade1 root moment Mx[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMy Mbdy:blade1 nodenr:   1 coo: blade1  blade 1 root':'Blade1 root moment My[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMz Mbdy:blade1 nodenr:   1 coo: blade1  blade 1 root':'Blade1 root moment Mz[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMx Mbdy:blade2 nodenr:   1 coo: blade2  blade 2 root':'Blade2 root moment Mx[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMy Mbdy:blade2 nodenr:   1 coo: blade2  blade 2 root':'Blade2 root moment My[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMz Mbdy:blade2 nodenr:   1 coo: blade2  blade 2 root':'Blade2 root moment Mz[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMx Mbdy:blade3 nodenr:   1 coo: blade3  blade 3 root':'Blade3 root moment Mx[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMy Mbdy:blade3 nodenr:   1 coo: blade3  blade 3 root':'Blade3 root moment My[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMz Mbdy:blade3 nodenr:   1 coo: blade3  blade 3 root':'Blade3 root moment Mz[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMx Mbdy:blade1 nodenr:  21 coo: blade1  blade 1 1/3 span':'Blade1 1/3 span moment Mx[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMy Mbdy:blade1 nodenr:  21 coo: blade1  blade 1 1/3 span':'Blade1 1/3 span moment My[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMz Mbdy:blade1 nodenr:  21 coo: blade1  blade 1 1/3 span':'Blade1 1/3 span moment Mz[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMx Mbdy:blade2 nodenr:  21 coo: blade2  blade 2 1/3 span':'Blade2 1/3 span moment Mx[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMy Mbdy:blade2 nodenr:  21 coo: blade2  blade 2 1/3 span':'Blade2 1/3 span moment My[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMz Mbdy:blade2 nodenr:  21 coo: blade2  blade 2 1/3 span':'Blade2 1/3 span moment Mz[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMx Mbdy:blade3 nodenr:  21 coo: blade3  blade 3 1/3 span':'Blade3 1/3 span moment Mx[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMy Mbdy:blade3 nodenr:  21 coo: blade3  blade 3 1/3 span':'Blade3 1/3 span moment My[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMz Mbdy:blade3 nodenr:  21 coo: blade3  blade 3 1/3 span':'Blade3 1/3 span moment Mz[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMx Mbdy:blade1 nodenr:  27 coo: blade1  blade 1 2/3 span':'Blade1 2/3 span moment Mx[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMy Mbdy:blade1 nodenr:  27 coo: blade1  blade 1 2/3 span':'Blade1 2/3 span moment My[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMz Mbdy:blade1 nodenr:  27 coo: blade1  blade 1 2/3 span':'Blade1 2/3 span moment Mz[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMx Mbdy:blade2 nodenr:  27 coo: blade2  blade 2 2/3 span':'Blade2 2/3 span moment Mx[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMy Mbdy:blade2 nodenr:  27 coo: blade2  blade 2 2/3 span':'Blade2 2/3 span moment My[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMz Mbdy:blade2 nodenr:  27 coo: blade2  blade 2 2/3 span':'Blade2 2/3 span moment Mz[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMx Mbdy:blade3 nodenr:  27 coo: blade3  blade 3 2/3 span':'Blade3 2/3 span moment Mx[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMy Mbdy:blade3 nodenr:  27 coo: blade3  blade 3 2/3 span':'Blade3 2/3 span moment My[kNm]'}, inplace = True)
Data.rename(columns = {'MomentMz Mbdy:blade3 nodenr:  27 coo: blade3  blade 3 2/3 span':'Blade3 2/3 span moment Mz[kNm]'}, inplace = True)

# Shear forces
Data.rename(columns = {'Force  Fx Mbdy:monopile nodenr:   4 coo: monopile  mudline':'Mudline force Fx[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fy Mbdy:monopile nodenr:   4 coo: monopile  mudline':'Mudline force Fy[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fz Mbdy:monopile nodenr:   4 coo: monopile  mudline':'Mudline force Fz[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fx Mbdy:monopile nodenr:   7 coo: monopile  waterline':'Waterline force Fx[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fy Mbdy:monopile nodenr:   7 coo: monopile  waterline':'Waterline force Fy[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fz Mbdy:monopile nodenr:   7 coo: monopile  waterline':'Waterline force Fz[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fx Mbdy:tower nodenr:   1 coo: tower  tower base':'Tower base force Fx[km]'}, inplace = True)
Data.rename(columns = {'Force  Fy Mbdy:tower nodenr:   1 coo: tower  tower base':'Tower base force Fy[km]'}, inplace = True)
Data.rename(columns = {'Force  Fz Mbdy:tower nodenr:   1 coo: tower  tower base':'Tower base force Fz[km]'}, inplace = True)
Data.rename(columns = {'Force  Fx Mbdy:tower nodenr:   5 coo: tower  tower mid':'Tower mid force Fx[km]'}, inplace = True)
Data.rename(columns = {'Force  Fy Mbdy:tower nodenr:   5 coo: tower  tower mid':'Tower mid force Fy[km]'}, inplace = True)
Data.rename(columns = {'Force  Fz Mbdy:tower nodenr:   5 coo: tower  tower mid':'Tower mid force Fz[km]'}, inplace = True)
Data.rename(columns = {'Force  Fx Mbdy:tower nodenr:  10 coo: tower  tower yaw bearing':'Tower top force Fx[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fy Mbdy:tower nodenr:  10 coo: tower  tower yaw bearing':'Tower top force Fy[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fz Mbdy:tower nodenr:  10 coo: tower  tower yaw bearing':'Tower top force Fz[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fx Mbdy:blade1 nodenr:   1 coo: blade1  blade 1 root':'Blade1 root force Fx[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fy Mbdy:blade1 nodenr:   1 coo: blade1  blade 1 root':'Blade1 root force Fy[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fz Mbdy:blade1 nodenr:   1 coo: blade1  blade 1 root':'Blade1 root force Fz[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fx Mbdy:blade2 nodenr:   1 coo: blade2  blade 2 root':'Blade2 root force Fx[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fy Mbdy:blade2 nodenr:   1 coo: blade2  blade 2 root':'Blade2 root force Fy[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fz Mbdy:blade2 nodenr:   1 coo: blade2  blade 2 root':'Blade2 root force Fz[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fx Mbdy:blade3 nodenr:   1 coo: blade3  blade 3 root':'Blade3 root force Fx[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fy Mbdy:blade3 nodenr:   1 coo: blade3  blade 3 root':'Blade3 root force Fy[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fz Mbdy:blade3 nodenr:   1 coo: blade3  blade 3 root':'Blade3 root force Fz[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fx Mbdy:blade1 nodenr:  21 coo: blade1  blade 1 1/3 span':'Blade1 1/3 span force Fx[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fy Mbdy:blade1 nodenr:  21 coo: blade1  blade 1 1/3 span':'Blade1 1/3 span force Fy[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fz Mbdy:blade1 nodenr:  21 coo: blade1  blade 1 1/3 span':'Blade1 1/3 span force Fz[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fx Mbdy:blade2 nodenr:  21 coo: blade2  blade 2 1/3 span':'Blade2 1/3 span force Fx[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fy Mbdy:blade2 nodenr:  21 coo: blade2  blade 2 1/3 span':'Blade2 1/3 span force Fy[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fz Mbdy:blade2 nodenr:  21 coo: blade2  blade 2 1/3 span':'Blade2 1/3 span force Fz[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fx Mbdy:blade3 nodenr:  21 coo: blade3  blade 3 1/3 span':'Blade3 1/3 span force Fx[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fy Mbdy:blade3 nodenr:  21 coo: blade3  blade 3 1/3 span':'Blade3 1/3 span force Fy[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fz Mbdy:blade3 nodenr:  21 coo: blade3  blade 3 1/3 span':'Blade3 1/3 span force Fz[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fx Mbdy:blade1 nodenr:  27 coo: blade1  blade 1 2/3 span':'Blade1 2/3 span force Fx[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fy Mbdy:blade1 nodenr:  27 coo: blade1  blade 1 2/3 span':'Blade1 2/3 span force Fy[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fz Mbdy:blade1 nodenr:  27 coo: blade1  blade 1 2/3 span':'Blade1 2/3 span force Fz[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fx Mbdy:blade2 nodenr:  27 coo: blade2  blade 2 2/3 span':'Blade2 2/3 span force Fx[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fy Mbdy:blade2 nodenr:  27 coo: blade2  blade 2 2/3 span':'Blade2 2/3 span force Fy[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fz Mbdy:blade2 nodenr:  27 coo: blade2  blade 2 2/3 span':'Blade2 2/3 span force Fz[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fx Mbdy:blade3 nodenr:  27 coo: blade3  blade 3 2/3 span':'Blade3 2/3 span force Fx[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fy Mbdy:blade3 nodenr:  27 coo: blade3  blade 3 2/3 span':'Blade3 2/3 span force Fy[kN]'}, inplace = True)
Data.rename(columns = {'Force  Fz Mbdy:blade3 nodenr:  27 coo: blade3  blade 3 2/3 span':'Blade3 2/3 span force Fz[kN]'}, inplace = True)

# Displacements and Accelerations
Data.rename(columns = {'State pos x  Mbdy:tower E-nr:   9 Z-rel:1.00 coo: global  tower top fa displ':'Tower top fore-aft displacement dx [m]'}, inplace = True)
Data.rename(columns = {'State pos y  Mbdy:tower E-nr:   9 Z-rel:1.00 coo: global  tower top ss displ':'Tower top side-side displacement dy [m]'}, inplace = True)
Data.rename(columns = {'State pos x  Mbdy:tower E-nr:   5 Z-rel:0.00 coo: global  tower mid fa displ':'Tower mid fore-aft displacement dx [m]'}, inplace = True)
Data.rename(columns = {'State pos y  Mbdy:tower E-nr:   5 Z-rel:0.00 coo: global  tower mid ss displ':'Tower mid side-side displacement dy [m]'}, inplace = True)
Data.rename(columns = {'State pos x  Mbdy:tower E-nr:   1 Z-rel:0.00 coo: global  tower base fa displ':'Tower base fore-aft displacement dx [m]'}, inplace = True)
Data.rename(columns = {'State pos y  Mbdy:tower E-nr:   1 Z-rel:0.00 coo: global  tower base ss displ':'Tower base side-side displacement dy [m]'}, inplace = True)
Data.rename(columns = {'State acc x  Mbdy:tower E-nr:   9 Z-rel:1.00 coo: global  tower top fa acc':'Tower top fore-aft acceleration ax [m/s2]'}, inplace = True)
Data.rename(columns = {'State acc y  Mbdy:tower E-nr:   9 Z-rel:1.00 coo: global  tower top ss acc':'Tower top side-side acceleration ay [m/s2]'}, inplace = True)
Data.rename(columns = {'State acc x  Mbdy:tower E-nr:   5 Z-rel:0.00 coo: global  tower mid fa acc':'Tower mid fore-aft acceleration ax [m/s2]'}, inplace = True)
Data.rename(columns = {'State acc y  Mbdy:tower E-nr:   5 Z-rel:0.00 coo: global  tower mid ss acc':'Tower mid side-side acceleration ay [m/s2]'}, inplace = True)
Data.rename(columns = {'State acc x  Mbdy:tower E-nr:   1 Z-rel:0.00 coo: global  tower base fa acc':'Tower base fore-aft acceleration ax [m/s2]'}, inplace = True)
Data.rename(columns = {'State acc y  Mbdy:tower E-nr:   1 Z-rel:0.00 coo: global  tower base ss acc':'Tower base side-side acceleration ay [m/s2]'}, inplace = True)
Data.rename(columns = {'State pos x  Mbdy:blade1 E-nr:   9 Z-rel:1.00 coo: blade1  blade 1 tip pos':'Blade1 tip position x [m]'}, inplace = True)
Data.rename(columns = {'State pos y  Mbdy:blade1 E-nr:   9 Z-rel:1.00 coo: blade1  blade 1 tip pos':'Blade1 tip position y [m]'}, inplace = True)
Data.rename(columns = {'State pos z  Mbdy:blade1 E-nr:   9 Z-rel:1.00 coo: blade1  blade 1 tip pos':'Blade1 tip position z [m]'}, inplace = True)
Data.rename(columns = {'State pos x  Mbdy:blade2 E-nr:   9 Z-rel:1.00 coo: blade2  blade 2 tip pos':'Blade2 tip position x [m]'}, inplace = True)
Data.rename(columns = {'State pos y  Mbdy:blade2 E-nr:   9 Z-rel:1.00 coo: blade2  blade 2 tip pos':'Blade2 tip position y [m]'}, inplace = True)
Data.rename(columns = {'State pos z  Mbdy:blade2 E-nr:   9 Z-rel:1.00 coo: blade2  blade 2 tip pos':'Blade2 tip position z [m]'}, inplace = True)
Data.rename(columns = {'State pos x  Mbdy:blade3 E-nr:   9 Z-rel:1.00 coo: blade3  blade 3 tip pos':'Blade3 tip position x [m]'}, inplace = True)
Data.rename(columns = {'State pos y  Mbdy:blade3 E-nr:   9 Z-rel:1.00 coo: blade3  blade 3 tip pos':'Blade3 tip position y [m]'}, inplace = True)
Data.rename(columns = {'State pos z  Mbdy:blade3 E-nr:   9 Z-rel:1.00 coo: blade3  blade 3 tip pos':'Blade3 tip position z [m]'}, inplace = True)

# Local wind speed
Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos    0.00,   0.00,-150.00':'Free wind speed Vx pos    0.00,   0.00,-150.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos    0.00,   0.00,-150.00':'Free wind speed Vy pos    0.00,   0.00,-150.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos    0.00,   0.00,-150.00':'Free wind speed Vz pos    0.00,   0.00,-150.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos  -78.00,   0.00,-150.00':'Free wind speed Vx pos  -78.00,   0.00,-150.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos  -78.00,   0.00,-150.00':'Free wind speed Vy pos  -78.00,   0.00,-150.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos  -78.00,   0.00,-150.00':'Free wind speed Vz pos  -78.00,   0.00,-150.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos   78.00,   0.00,-150.00':'Free wind speed Vx pos   78.00,   0.00,-150.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos   78.00,   0.00,-150.00':'Free wind speed Vy pos   78.00,   0.00,-150.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos   78.00,   0.00,-150.00':'Free wind speed Vz pos   78.00,   0.00,-150.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos    0.00,   0.00, -72.00':'Free wind speed Vx pos    0.00,   0.00, -72.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos    0.00,   0.00, -72.00':'Free wind speed Vy pos    0.00,   0.00, -72.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos    0.00,   0.00, -72.00':'Free wind speed Vz pos    0.00,   0.00, -72.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos    0.00,   0.00,-228.00':'Free wind speed Vx pos    0.00,   0.00,-228.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos    0.00,   0.00,-228.00':'Free wind speed Vy pos    0.00,   0.00,-228.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos    0.00,   0.00,-228.00':'Free wind speed Vz pos    0.00,   0.00,-228.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos   55.00,   0.00,-205.00':'Free wind speed Vx pos   55.00,   0.00,-205.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos   55.00,   0.00,-205.00':'Free wind speed Vy pos   55.00,   0.00,-205.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos   55.00,   0.00,-205.00':'Free wind speed Vz pos   55.00,   0.00,-205.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos   55.00,   0.00, -95.00':'Free wind speed Vx pos   55.00,   0.00, -95.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos   55.00,   0.00, -95.00':'Free wind speed Vy pos   55.00,   0.00, -95.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos   55.00,   0.00, -95.00':'Free wind speed Vz pos   55.00,   0.00, -95.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos  -55.00,   0.00,-205.00':'Free wind speed Vx pos  -55.00,   0.00,-205.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos  -55.00,   0.00,-205.00':'Free wind speed Vy pos  -55.00,   0.00,-205.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos  -55.00,   0.00,-205.00':'Free wind speed Vz pos  -55.00,   0.00,-205.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos  -55.00,   0.00, -95.00':'Free wind speed Vx pos  -55.00,   0.00, -95.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos  -55.00,   0.00, -95.00':'Free wind speed Vy pos  -55.00,   0.00, -95.00'}, inplace = True)
Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos  -55.00,   0.00, -95.00':'Free wind speed Vz pos  -55.00,   0.00, -95.00'}, inplace = True)

# Water elevation
Data.rename(columns = {'Water surface gl. coo, at gl. coo, x,y=   0.00,   0.00':'Water surface elevation [m]'}, inplace = True)

# %%
Data.columns.values
# Out:
# array(['Time', 'Rotor azimuth [deg]', 'Rotor rotational speed [rpm]',
#        'Blade 1 pitch angle [deg]', 'pitch1 angle speed',
#        'Blade 2 pitch angle [deg]', 'pitch2 angle speed',
#        'Blade 3 pitch angle [deg]', 'pitch3 angle speed', 'Rotor speed',
#        'Aero rotor torque', 'Aero rotor power', 'Aero rotor thrust',
#        'Generator LSS torque [Nm]', 'Electrical power [W]',
#        'Bedframe moment [Nm]', 'Generator HSS torque [Nm]',
#        'generator_servo inpvec   8  grid flag [0=run/1=stop]',
#        'Mudline moment Mx[kNm]', 'Mudline moment My[kNm]',
#        'Mudline moment Mz[kNm]',
#        'MomentMx Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
#        'MomentMy Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
#        'MomentMz Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
#        'Waterline moment Mx[kNm]', 'Waterline moment My[kNm]',
#        'Waterline moment Mz[kNm]', 'Tower base moment Mx[kNm]',
# ...

# %%
Data.drop(columns = {'Aero rotor torque','Aero rotor power','Aero rotor thrust',
                     'Rotor speed','pitch1 angle speed','pitch2 angle speed','pitch3 angle speed',
                     'MomentMx Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
                     'MomentMy Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
                     'MomentMz Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
                     'Force  Fx Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
                     'Force  Fy Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
                     'Force  Fz Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
                       'MomentMx Mbdy:shaft nodenr:   1 coo: shaft  main bearing',
                       'MomentMy Mbdy:shaft nodenr:   1 coo: shaft  main bearing',                     
                       'Force  Fx Mbdy:shaft nodenr:   1 coo: shaft  main bearing',
                       'Force  Fy Mbdy:shaft nodenr:   1 coo: shaft  main bearing',
                       'Force  Fz Mbdy:shaft nodenr:   1 coo: shaft  main bearing',
                       'State pos x  Mbdy:blade1 E-nr:   9 Z-rel:1.00 coo: global  gl blade 1 tip pos',
                       'State pos y  Mbdy:blade1 E-nr:   9 Z-rel:1.00 coo: global  gl blade 1 tip pos',
                       'State pos z  Mbdy:blade1 E-nr:   9 Z-rel:1.00 coo: global  gl blade 1 tip pos',                     
                     'Wind speed Vx of blade   1 at radius  71.63, global coo.',
                       'Angle of attack of blade   1 at radius  71.63',
                       'Angle of attack of blade   2 at radius  71.63',
                       'Angle of attack of blade   3 at radius  71.63',
                       'Cl of blade   1 at radius  71.63',
                       'Cl of blade   2 at radius  71.63',
                       'Cl of blade   3 at radius  71.63',
                       'Cd of blade   1 at radius  71.63',
                       'Cd of blade   2 at radius  71.63',
                       'Cd of blade   3 at radius  71.63', 
                       'dtu_we_controller inpvec   1  generator torque reference [nm]',
                       'dtu_we_controller inpvec   2  pitch angle reference of blade 1 [rad]',
                       'dtu_we_controller inpvec   3  pitch angle reference of blade 2 [rad]',
                       'dtu_we_controller inpvec   4  pitch angle reference of blade 3 [rad]',
                       'dtu_we_controller inpvec   5  power reference [w]',
                       'dtu_we_controller inpvec   6  filtered wind speed [m/s]',
                       'dtu_we_controller inpvec   7  filtered rotor speed [rad/s]',
                       'dtu_we_controller inpvec   8  filtered rotor speed error for torque [rad/s]',
                       'dtu_we_controller inpvec   9  bandpass filtered rotor speed [rad/s]',
                       'dtu_we_controller inpvec  10  proportional term of torque contr. [nm]',
                       'dtu_we_controller inpvec  11  integral term of torque controller [nm]',
                       'dtu_we_controller inpvec  12  minimum limit of torque [nm]',
                       'dtu_we_controller inpvec  13  maximum limit of torque [nm]',
                       'dtu_we_controller inpvec  14  torque limit switch based on pitch [-]',
                       'dtu_we_controller inpvec  15  filtered rotor speed error for pitch [rad/s]',
                       'dtu_we_controller inpvec  16  power error for pitch [w]',
                       'dtu_we_controller inpvec  17  proportional term of pitch controller [rad]',
                       'dtu_we_controller inpvec  18  integral term of pitch controller [rad]',
                       'dtu_we_controller inpvec  19  minimum limit of pitch [rad]',
                       'dtu_we_controller inpvec  20  maximum limit of pitch [rad]',
                       'dtu_we_controller inpvec  21  torque reference from dt dammper [nm]',
                       'dtu_we_controller inpvec  22  status signal [-]',
                       'dtu_we_controller inpvec  23  total added pitch rate [rad/s]',
                       'dtu_we_controller inpvec  24  filtered mean pitch for gain sch [rad]',
                       'dtu_we_controller inpvec  25  flag for mechnical brake [0=off/1=on]',
                       'dtu_we_controller inpvec  26  flag for emergency pitch stop [0=off/1=on]',
                       'dtu_we_controller inpvec  27  lp filtered acceleration level [m/s^2]',
                       'dtu_we_controller inpvec  31  monitored average of reference pitch [rad]',
                       'dtu_we_controller inpvec  32  monitored ave. of actual pitch (blade 1) [rad]',
                       'generator_servo inpvec   8  grid flag [0=run/1=stop]',
                       'mech_brake inpvec   3  brake torque [nm]',
                       'servo_with_limits inpvec   1  pitch 1 [rad]',
                       'servo_with_limits inpvec   2  pitch 2 [rad]',
                       'servo_with_limits inpvec   3  pitch 3 [rad]',
                       'towerclearance_mblade inpvec   1  bltip tow min d [m]'}, inplace = True)

# %%
Data.columns.values
# Out:
# array(['Time', 'Rotor azimuth [deg]', 'Rotor rotational speed [rpm]',
#        'Blade 1 pitch angle [deg]', 'Blade 2 pitch angle [deg]',
#        'Blade 3 pitch angle [deg]', 'Generator LSS torque [Nm]',
#        'Electrical power [W]', 'Bedframe moment [Nm]',
#        'Generator HSS torque [Nm]', 'Mudline moment Mx[kNm]',
#        'Mudline moment My[kNm]', 'Mudline moment Mz[kNm]',
#        'Waterline moment Mx[kNm]', 'Waterline moment My[kNm]',
#        'Waterline moment Mz[kNm]', 'Tower base moment Mx[kNm]',
#        'Tower base moment My[kNm]', 'Tower base moment Mz[kNm]',
#        'Tower mid moment Mx[kNm]', 'Tower mid moment My[kNm]',
#        'Tower mid moment Mz[kNm]', 'Tower top moment Mx[kNm]',
#        'Tower top moment My[kNm]', 'Tower top moment Mz[kNm]',
#        'Low-speed shaft torque [kNm]', 'Blade1 root moment Mx[kNm]',
#        'Blade1 root moment My[kNm]', 'Blade1 root moment Mz[kNm]',
#        'Blade2 root moment Mx[kNm]', 'Blade2 root moment My[kNm]',
# ...

# %%
Data.set_index('Time', inplace = True)

# %%
outfilename = 'VS_benchmark_timeseries_PointNo' + str(i+1) + '.csv'
Data.to_csv(outfilename, sep = ';')

# %%
Data
# Out:
#             Rotor azimuth [deg]  Rotor rotational speed [rpm]  \
# Time
# 0.000000               0.112497                      1.909761
# 0.021875               0.224994                      1.909761
# 0.021875               0.348741                      1.909761
# 0.043750               0.461238                      1.910245
# 0.043750               0.573735                      1.910970
# ...                         ...                           ...
# 699.956250           344.994550                      7.501164
# 699.978125           345.444538                      7.501406
# 699.978125           345.894526                      7.501648
# 700.000000           346.344514                      7.502373
# 700.000000           346.794502                      7.503099
#
#             Blade 1 pitch angle [deg]  Blade 2 pitch angle [deg]  \
# Time
# 0.000000                     0.000074                   0.000074
# 0.021875                     0.000074                   0.000074
# ...

# %%
Nfiles = 10
for i in range(Nfiles):
    print(i)
    fname = str('z:\StudyData\VS_Benchmark\TimeSeries\IEA_15MW_RWT_VS_BenchmarkStudy_PointNo' + str(i+1) + '.sel')
    res = Hawc2io.ReadHawc2(fname)
    sig = res.ReadAll()
    Data = pd.DataFrame(data = sig, columns = res.ChInfo[2])
    # CHANGE CHANNEL NAMES

    # General channels
    Data.rename(columns = {'shaft_rot angle':'Rotor azimuth [deg]'}, inplace = True)
    Data.rename(columns = {'shaft_rot angle speed':'Rotor rotational speed [rpm]'}, inplace = True)
    Data.rename(columns = {'pitch1 angle':'Blade 1 pitch angle [deg]'}, inplace = True)
    Data.rename(columns = {'pitch2 angle':'Blade 2 pitch angle [deg]'}, inplace = True)
    Data.rename(columns = {'pitch3 angle':'Blade 3 pitch angle [deg]'}, inplace = True)
    Data.rename(columns = {'MomentMz Mbdy:shaft nodenr:   1 coo: shaft  main bearing':'Low-speed shaft torque [kNm]'}, inplace = True)
    Data.rename(columns = {'generator_servo inpvec   1  mgen lss [nm]':'Generator LSS torque [Nm]'}, inplace = True)
    Data.rename(columns = {'generator_servo inpvec   2  pelec [w]':'Electrical power [W]'}, inplace = True)
    Data.rename(columns = {'generator_servo inpvec   3  mframe [nm]':'Bedframe moment [Nm]'}, inplace = True)
    Data.rename(columns = {'generator_servo inpvec   4  mgen hss [nm]':'Generator HSS torque [Nm]'}, inplace = True)

    # Bending moments
    Data.rename(columns = {'MomentMx Mbdy:monopile nodenr:   4 coo: monopile  mudline':'Mudline moment Mx[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMy Mbdy:monopile nodenr:   4 coo: monopile  mudline':'Mudline moment My[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMz Mbdy:monopile nodenr:   4 coo: monopile  mudline':'Mudline moment Mz[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMx Mbdy:monopile nodenr:   7 coo: monopile  waterline':'Waterline moment Mx[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMy Mbdy:monopile nodenr:   7 coo: monopile  waterline':'Waterline moment My[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMz Mbdy:monopile nodenr:   7 coo: monopile  waterline':'Waterline moment Mz[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMx Mbdy:tower nodenr:   1 coo: tower  tower base':'Tower base moment Mx[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMy Mbdy:tower nodenr:   1 coo: tower  tower base':'Tower base moment My[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMz Mbdy:tower nodenr:   1 coo: tower  tower base':'Tower base moment Mz[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMx Mbdy:tower nodenr:   5 coo: tower  tower mid':'Tower mid moment Mx[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMy Mbdy:tower nodenr:   5 coo: tower  tower mid':'Tower mid moment My[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMz Mbdy:tower nodenr:   5 coo: tower  tower mid':'Tower mid moment Mz[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMx Mbdy:tower nodenr:  10 coo: tower  tower yaw bearing':'Tower top moment Mx[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMy Mbdy:tower nodenr:  10 coo: tower  tower yaw bearing':'Tower top moment My[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMz Mbdy:tower nodenr:  10 coo: tower  tower yaw bearing':'Tower top moment Mz[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMx Mbdy:blade1 nodenr:   1 coo: blade1  blade 1 root':'Blade1 root moment Mx[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMy Mbdy:blade1 nodenr:   1 coo: blade1  blade 1 root':'Blade1 root moment My[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMz Mbdy:blade1 nodenr:   1 coo: blade1  blade 1 root':'Blade1 root moment Mz[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMx Mbdy:blade2 nodenr:   1 coo: blade2  blade 2 root':'Blade2 root moment Mx[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMy Mbdy:blade2 nodenr:   1 coo: blade2  blade 2 root':'Blade2 root moment My[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMz Mbdy:blade2 nodenr:   1 coo: blade2  blade 2 root':'Blade2 root moment Mz[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMx Mbdy:blade3 nodenr:   1 coo: blade3  blade 3 root':'Blade3 root moment Mx[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMy Mbdy:blade3 nodenr:   1 coo: blade3  blade 3 root':'Blade3 root moment My[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMz Mbdy:blade3 nodenr:   1 coo: blade3  blade 3 root':'Blade3 root moment Mz[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMx Mbdy:blade1 nodenr:  21 coo: blade1  blade 1 1/3 span':'Blade1 1/3 span moment Mx[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMy Mbdy:blade1 nodenr:  21 coo: blade1  blade 1 1/3 span':'Blade1 1/3 span moment My[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMz Mbdy:blade1 nodenr:  21 coo: blade1  blade 1 1/3 span':'Blade1 1/3 span moment Mz[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMx Mbdy:blade2 nodenr:  21 coo: blade2  blade 2 1/3 span':'Blade2 1/3 span moment Mx[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMy Mbdy:blade2 nodenr:  21 coo: blade2  blade 2 1/3 span':'Blade2 1/3 span moment My[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMz Mbdy:blade2 nodenr:  21 coo: blade2  blade 2 1/3 span':'Blade2 1/3 span moment Mz[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMx Mbdy:blade3 nodenr:  21 coo: blade3  blade 3 1/3 span':'Blade3 1/3 span moment Mx[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMy Mbdy:blade3 nodenr:  21 coo: blade3  blade 3 1/3 span':'Blade3 1/3 span moment My[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMz Mbdy:blade3 nodenr:  21 coo: blade3  blade 3 1/3 span':'Blade3 1/3 span moment Mz[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMx Mbdy:blade1 nodenr:  27 coo: blade1  blade 1 2/3 span':'Blade1 2/3 span moment Mx[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMy Mbdy:blade1 nodenr:  27 coo: blade1  blade 1 2/3 span':'Blade1 2/3 span moment My[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMz Mbdy:blade1 nodenr:  27 coo: blade1  blade 1 2/3 span':'Blade1 2/3 span moment Mz[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMx Mbdy:blade2 nodenr:  27 coo: blade2  blade 2 2/3 span':'Blade2 2/3 span moment Mx[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMy Mbdy:blade2 nodenr:  27 coo: blade2  blade 2 2/3 span':'Blade2 2/3 span moment My[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMz Mbdy:blade2 nodenr:  27 coo: blade2  blade 2 2/3 span':'Blade2 2/3 span moment Mz[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMx Mbdy:blade3 nodenr:  27 coo: blade3  blade 3 2/3 span':'Blade3 2/3 span moment Mx[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMy Mbdy:blade3 nodenr:  27 coo: blade3  blade 3 2/3 span':'Blade3 2/3 span moment My[kNm]'}, inplace = True)
    Data.rename(columns = {'MomentMz Mbdy:blade3 nodenr:  27 coo: blade3  blade 3 2/3 span':'Blade3 2/3 span moment Mz[kNm]'}, inplace = True)

    # Shear forces
    Data.rename(columns = {'Force  Fx Mbdy:monopile nodenr:   4 coo: monopile  mudline':'Mudline force Fx[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fy Mbdy:monopile nodenr:   4 coo: monopile  mudline':'Mudline force Fy[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fz Mbdy:monopile nodenr:   4 coo: monopile  mudline':'Mudline force Fz[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fx Mbdy:monopile nodenr:   7 coo: monopile  waterline':'Waterline force Fx[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fy Mbdy:monopile nodenr:   7 coo: monopile  waterline':'Waterline force Fy[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fz Mbdy:monopile nodenr:   7 coo: monopile  waterline':'Waterline force Fz[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fx Mbdy:tower nodenr:   1 coo: tower  tower base':'Tower base force Fx[km]'}, inplace = True)
    Data.rename(columns = {'Force  Fy Mbdy:tower nodenr:   1 coo: tower  tower base':'Tower base force Fy[km]'}, inplace = True)
    Data.rename(columns = {'Force  Fz Mbdy:tower nodenr:   1 coo: tower  tower base':'Tower base force Fz[km]'}, inplace = True)
    Data.rename(columns = {'Force  Fx Mbdy:tower nodenr:   5 coo: tower  tower mid':'Tower mid force Fx[km]'}, inplace = True)
    Data.rename(columns = {'Force  Fy Mbdy:tower nodenr:   5 coo: tower  tower mid':'Tower mid force Fy[km]'}, inplace = True)
    Data.rename(columns = {'Force  Fz Mbdy:tower nodenr:   5 coo: tower  tower mid':'Tower mid force Fz[km]'}, inplace = True)
    Data.rename(columns = {'Force  Fx Mbdy:tower nodenr:  10 coo: tower  tower yaw bearing':'Tower top force Fx[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fy Mbdy:tower nodenr:  10 coo: tower  tower yaw bearing':'Tower top force Fy[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fz Mbdy:tower nodenr:  10 coo: tower  tower yaw bearing':'Tower top force Fz[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fx Mbdy:blade1 nodenr:   1 coo: blade1  blade 1 root':'Blade1 root force Fx[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fy Mbdy:blade1 nodenr:   1 coo: blade1  blade 1 root':'Blade1 root force Fy[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fz Mbdy:blade1 nodenr:   1 coo: blade1  blade 1 root':'Blade1 root force Fz[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fx Mbdy:blade2 nodenr:   1 coo: blade2  blade 2 root':'Blade2 root force Fx[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fy Mbdy:blade2 nodenr:   1 coo: blade2  blade 2 root':'Blade2 root force Fy[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fz Mbdy:blade2 nodenr:   1 coo: blade2  blade 2 root':'Blade2 root force Fz[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fx Mbdy:blade3 nodenr:   1 coo: blade3  blade 3 root':'Blade3 root force Fx[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fy Mbdy:blade3 nodenr:   1 coo: blade3  blade 3 root':'Blade3 root force Fy[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fz Mbdy:blade3 nodenr:   1 coo: blade3  blade 3 root':'Blade3 root force Fz[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fx Mbdy:blade1 nodenr:  21 coo: blade1  blade 1 1/3 span':'Blade1 1/3 span force Fx[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fy Mbdy:blade1 nodenr:  21 coo: blade1  blade 1 1/3 span':'Blade1 1/3 span force Fy[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fz Mbdy:blade1 nodenr:  21 coo: blade1  blade 1 1/3 span':'Blade1 1/3 span force Fz[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fx Mbdy:blade2 nodenr:  21 coo: blade2  blade 2 1/3 span':'Blade2 1/3 span force Fx[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fy Mbdy:blade2 nodenr:  21 coo: blade2  blade 2 1/3 span':'Blade2 1/3 span force Fy[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fz Mbdy:blade2 nodenr:  21 coo: blade2  blade 2 1/3 span':'Blade2 1/3 span force Fz[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fx Mbdy:blade3 nodenr:  21 coo: blade3  blade 3 1/3 span':'Blade3 1/3 span force Fx[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fy Mbdy:blade3 nodenr:  21 coo: blade3  blade 3 1/3 span':'Blade3 1/3 span force Fy[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fz Mbdy:blade3 nodenr:  21 coo: blade3  blade 3 1/3 span':'Blade3 1/3 span force Fz[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fx Mbdy:blade1 nodenr:  27 coo: blade1  blade 1 2/3 span':'Blade1 2/3 span force Fx[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fy Mbdy:blade1 nodenr:  27 coo: blade1  blade 1 2/3 span':'Blade1 2/3 span force Fy[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fz Mbdy:blade1 nodenr:  27 coo: blade1  blade 1 2/3 span':'Blade1 2/3 span force Fz[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fx Mbdy:blade2 nodenr:  27 coo: blade2  blade 2 2/3 span':'Blade2 2/3 span force Fx[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fy Mbdy:blade2 nodenr:  27 coo: blade2  blade 2 2/3 span':'Blade2 2/3 span force Fy[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fz Mbdy:blade2 nodenr:  27 coo: blade2  blade 2 2/3 span':'Blade2 2/3 span force Fz[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fx Mbdy:blade3 nodenr:  27 coo: blade3  blade 3 2/3 span':'Blade3 2/3 span force Fx[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fy Mbdy:blade3 nodenr:  27 coo: blade3  blade 3 2/3 span':'Blade3 2/3 span force Fy[kN]'}, inplace = True)
    Data.rename(columns = {'Force  Fz Mbdy:blade3 nodenr:  27 coo: blade3  blade 3 2/3 span':'Blade3 2/3 span force Fz[kN]'}, inplace = True)

    # Displacements and Accelerations
    Data.rename(columns = {'State pos x  Mbdy:tower E-nr:   9 Z-rel:1.00 coo: global  tower top fa displ':'Tower top fore-aft displacement dx [m]'}, inplace = True)
    Data.rename(columns = {'State pos y  Mbdy:tower E-nr:   9 Z-rel:1.00 coo: global  tower top ss displ':'Tower top side-side displacement dy [m]'}, inplace = True)
    Data.rename(columns = {'State pos x  Mbdy:tower E-nr:   5 Z-rel:0.00 coo: global  tower mid fa displ':'Tower mid fore-aft displacement dx [m]'}, inplace = True)
    Data.rename(columns = {'State pos y  Mbdy:tower E-nr:   5 Z-rel:0.00 coo: global  tower mid ss displ':'Tower mid side-side displacement dy [m]'}, inplace = True)
    Data.rename(columns = {'State pos x  Mbdy:tower E-nr:   1 Z-rel:0.00 coo: global  tower base fa displ':'Tower base fore-aft displacement dx [m]'}, inplace = True)
    Data.rename(columns = {'State pos y  Mbdy:tower E-nr:   1 Z-rel:0.00 coo: global  tower base ss displ':'Tower base side-side displacement dy [m]'}, inplace = True)
    Data.rename(columns = {'State acc x  Mbdy:tower E-nr:   9 Z-rel:1.00 coo: global  tower top fa acc':'Tower top fore-aft acceleration ax [m/s2]'}, inplace = True)
    Data.rename(columns = {'State acc y  Mbdy:tower E-nr:   9 Z-rel:1.00 coo: global  tower top ss acc':'Tower top side-side acceleration ay [m/s2]'}, inplace = True)
    Data.rename(columns = {'State acc x  Mbdy:tower E-nr:   5 Z-rel:0.00 coo: global  tower mid fa acc':'Tower mid fore-aft acceleration ax [m/s2]'}, inplace = True)
    Data.rename(columns = {'State acc y  Mbdy:tower E-nr:   5 Z-rel:0.00 coo: global  tower mid ss acc':'Tower mid side-side acceleration ay [m/s2]'}, inplace = True)
    Data.rename(columns = {'State acc x  Mbdy:tower E-nr:   1 Z-rel:0.00 coo: global  tower base fa acc':'Tower base fore-aft acceleration ax [m/s2]'}, inplace = True)
    Data.rename(columns = {'State acc y  Mbdy:tower E-nr:   1 Z-rel:0.00 coo: global  tower base ss acc':'Tower base side-side acceleration ay [m/s2]'}, inplace = True)
    Data.rename(columns = {'State pos x  Mbdy:blade1 E-nr:   9 Z-rel:1.00 coo: blade1  blade 1 tip pos':'Blade1 tip position x [m]'}, inplace = True)
    Data.rename(columns = {'State pos y  Mbdy:blade1 E-nr:   9 Z-rel:1.00 coo: blade1  blade 1 tip pos':'Blade1 tip position y [m]'}, inplace = True)
    Data.rename(columns = {'State pos z  Mbdy:blade1 E-nr:   9 Z-rel:1.00 coo: blade1  blade 1 tip pos':'Blade1 tip position z [m]'}, inplace = True)
    Data.rename(columns = {'State pos x  Mbdy:blade2 E-nr:   9 Z-rel:1.00 coo: blade2  blade 2 tip pos':'Blade2 tip position x [m]'}, inplace = True)
    Data.rename(columns = {'State pos y  Mbdy:blade2 E-nr:   9 Z-rel:1.00 coo: blade2  blade 2 tip pos':'Blade2 tip position y [m]'}, inplace = True)
    Data.rename(columns = {'State pos z  Mbdy:blade2 E-nr:   9 Z-rel:1.00 coo: blade2  blade 2 tip pos':'Blade2 tip position z [m]'}, inplace = True)
    Data.rename(columns = {'State pos x  Mbdy:blade3 E-nr:   9 Z-rel:1.00 coo: blade3  blade 3 tip pos':'Blade3 tip position x [m]'}, inplace = True)
    Data.rename(columns = {'State pos y  Mbdy:blade3 E-nr:   9 Z-rel:1.00 coo: blade3  blade 3 tip pos':'Blade3 tip position y [m]'}, inplace = True)
    Data.rename(columns = {'State pos z  Mbdy:blade3 E-nr:   9 Z-rel:1.00 coo: blade3  blade 3 tip pos':'Blade3 tip position z [m]'}, inplace = True)

    # Local wind speed
    Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos    0.00,   0.00,-150.00':'Free wind speed Vx pos    0.00,   0.00,-150.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos    0.00,   0.00,-150.00':'Free wind speed Vy pos    0.00,   0.00,-150.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos    0.00,   0.00,-150.00':'Free wind speed Vz pos    0.00,   0.00,-150.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos  -78.00,   0.00,-150.00':'Free wind speed Vx pos  -78.00,   0.00,-150.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos  -78.00,   0.00,-150.00':'Free wind speed Vy pos  -78.00,   0.00,-150.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos  -78.00,   0.00,-150.00':'Free wind speed Vz pos  -78.00,   0.00,-150.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos   78.00,   0.00,-150.00':'Free wind speed Vx pos   78.00,   0.00,-150.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos   78.00,   0.00,-150.00':'Free wind speed Vy pos   78.00,   0.00,-150.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos   78.00,   0.00,-150.00':'Free wind speed Vz pos   78.00,   0.00,-150.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos    0.00,   0.00, -72.00':'Free wind speed Vx pos    0.00,   0.00, -72.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos    0.00,   0.00, -72.00':'Free wind speed Vy pos    0.00,   0.00, -72.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos    0.00,   0.00, -72.00':'Free wind speed Vz pos    0.00,   0.00, -72.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos    0.00,   0.00,-228.00':'Free wind speed Vx pos    0.00,   0.00,-228.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos    0.00,   0.00,-228.00':'Free wind speed Vy pos    0.00,   0.00,-228.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos    0.00,   0.00,-228.00':'Free wind speed Vz pos    0.00,   0.00,-228.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos   55.00,   0.00,-205.00':'Free wind speed Vx pos   55.00,   0.00,-205.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos   55.00,   0.00,-205.00':'Free wind speed Vy pos   55.00,   0.00,-205.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos   55.00,   0.00,-205.00':'Free wind speed Vz pos   55.00,   0.00,-205.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos   55.00,   0.00, -95.00':'Free wind speed Vx pos   55.00,   0.00, -95.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos   55.00,   0.00, -95.00':'Free wind speed Vy pos   55.00,   0.00, -95.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos   55.00,   0.00, -95.00':'Free wind speed Vz pos   55.00,   0.00, -95.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos  -55.00,   0.00,-205.00':'Free wind speed Vx pos  -55.00,   0.00,-205.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos  -55.00,   0.00,-205.00':'Free wind speed Vy pos  -55.00,   0.00,-205.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos  -55.00,   0.00,-205.00':'Free wind speed Vz pos  -55.00,   0.00,-205.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vx, gl. coo, of gl. pos  -55.00,   0.00, -95.00':'Free wind speed Vx pos  -55.00,   0.00, -95.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vy, gl. coo, of gl. pos  -55.00,   0.00, -95.00':'Free wind speed Vy pos  -55.00,   0.00, -95.00'}, inplace = True)
    Data.rename(columns = {'Free wind speed Vz, gl. coo, of gl. pos  -55.00,   0.00, -95.00':'Free wind speed Vz pos  -55.00,   0.00, -95.00'}, inplace = True)

    # Water elevation
    Data.rename(columns = {'Water surface gl. coo, at gl. coo, x,y=   0.00,   0.00':'Water surface elevation [m]'}, inplace = True)
    Data.drop(columns = {'Aero rotor torque','Aero rotor power','Aero rotor thrust',
                     'Rotor speed','pitch1 angle speed','pitch2 angle speed','pitch3 angle speed',
                     'MomentMx Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
                     'MomentMy Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
                     'MomentMz Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
                     'Force  Fx Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
                     'Force  Fy Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
                     'Force  Fz Mbdy:monopile nodenr:   5 coo: monopile  10m above mudline',
                       'MomentMx Mbdy:shaft nodenr:   1 coo: shaft  main bearing',
                       'MomentMy Mbdy:shaft nodenr:   1 coo: shaft  main bearing',                     
                       'Force  Fx Mbdy:shaft nodenr:   1 coo: shaft  main bearing',
                       'Force  Fy Mbdy:shaft nodenr:   1 coo: shaft  main bearing',
                       'Force  Fz Mbdy:shaft nodenr:   1 coo: shaft  main bearing',
                       'State pos x  Mbdy:blade1 E-nr:   9 Z-rel:1.00 coo: global  gl blade 1 tip pos',
                       'State pos y  Mbdy:blade1 E-nr:   9 Z-rel:1.00 coo: global  gl blade 1 tip pos',
                       'State pos z  Mbdy:blade1 E-nr:   9 Z-rel:1.00 coo: global  gl blade 1 tip pos',                     
                     'Wind speed Vx of blade   1 at radius  71.63, global coo.',
                       'Angle of attack of blade   1 at radius  71.63',
                       'Angle of attack of blade   2 at radius  71.63',
                       'Angle of attack of blade   3 at radius  71.63',
                       'Cl of blade   1 at radius  71.63',
                       'Cl of blade   2 at radius  71.63',
                       'Cl of blade   3 at radius  71.63',
                       'Cd of blade   1 at radius  71.63',
                       'Cd of blade   2 at radius  71.63',
                       'Cd of blade   3 at radius  71.63', 
                       'dtu_we_controller inpvec   1  generator torque reference [nm]',
                       'dtu_we_controller inpvec   2  pitch angle reference of blade 1 [rad]',
                       'dtu_we_controller inpvec   3  pitch angle reference of blade 2 [rad]',
                       'dtu_we_controller inpvec   4  pitch angle reference of blade 3 [rad]',
                       'dtu_we_controller inpvec   5  power reference [w]',
                       'dtu_we_controller inpvec   6  filtered wind speed [m/s]',
                       'dtu_we_controller inpvec   7  filtered rotor speed [rad/s]',
                       'dtu_we_controller inpvec   8  filtered rotor speed error for torque [rad/s]',
                       'dtu_we_controller inpvec   9  bandpass filtered rotor speed [rad/s]',
                       'dtu_we_controller inpvec  10  proportional term of torque contr. [nm]',
                       'dtu_we_controller inpvec  11  integral term of torque controller [nm]',
                       'dtu_we_controller inpvec  12  minimum limit of torque [nm]',
                       'dtu_we_controller inpvec  13  maximum limit of torque [nm]',
                       'dtu_we_controller inpvec  14  torque limit switch based on pitch [-]',
                       'dtu_we_controller inpvec  15  filtered rotor speed error for pitch [rad/s]',
                       'dtu_we_controller inpvec  16  power error for pitch [w]',
                       'dtu_we_controller inpvec  17  proportional term of pitch controller [rad]',
                       'dtu_we_controller inpvec  18  integral term of pitch controller [rad]',
                       'dtu_we_controller inpvec  19  minimum limit of pitch [rad]',
                       'dtu_we_controller inpvec  20  maximum limit of pitch [rad]',
                       'dtu_we_controller inpvec  21  torque reference from dt dammper [nm]',
                       'dtu_we_controller inpvec  22  status signal [-]',
                       'dtu_we_controller inpvec  23  total added pitch rate [rad/s]',
                       'dtu_we_controller inpvec  24  filtered mean pitch for gain sch [rad]',
                       'dtu_we_controller inpvec  25  flag for mechnical brake [0=off/1=on]',
                       'dtu_we_controller inpvec  26  flag for emergency pitch stop [0=off/1=on]',
                       'dtu_we_controller inpvec  27  lp filtered acceleration level [m/s^2]',
                       'dtu_we_controller inpvec  31  monitored average of reference pitch [rad]',
                       'dtu_we_controller inpvec  32  monitored ave. of actual pitch (blade 1) [rad]',
                       'generator_servo inpvec   8  grid flag [0=run/1=stop]',
                       'mech_brake inpvec   3  brake torque [nm]',
                       'servo_with_limits inpvec   1  pitch 1 [rad]',
                       'servo_with_limits inpvec   2  pitch 2 [rad]',
                       'servo_with_limits inpvec   3  pitch 3 [rad]',
                       'towerclearance_mblade inpvec   1  bltip tow min d [m]'}, inplace = True)
    Data.set_index('Time', inplace = True)
    outfilename = 'VS_benchmark_timeseries_PointNo' + str(i+1) + '.csv'
    Data.to_csv(outfilename, sep = ';')
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
